# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model_name="llama3-70b-8192",
    temperature=0,
    groq_api_key="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"
)
reponse=llm.invoke("resume for the flutter app developer")
print(reponse.content)
# Out:
# Here's a sample resume for a Flutter app developer:
#
# **Your Name**
# **Contact Information**
#
# **Summary:**
# Highly motivated and experienced Flutter app developer with a strong background in building scalable, efficient, and user-friendly mobile applications. Proficient in Dart, Flutter, and Firebase, with a passion for creating innovative and engaging user experiences.
#
# **Technical Skills:**
#
# * Programming languages: Dart, Java, Swift
# * Frameworks: Flutter, React Native
# * Databases: Firebase Realtime Database, Firestore, SQLite
# * APIs: RESTful APIs, GraphQL
# * Operating Systems: Android, iOS
# * Agile methodologies: Scrum, Kanban
# * Version control: Git, SVN
#
# **Professional Experience:**
#
# **Flutter App Developer, ABC Company (2020-Present)**
#
# * Designed and developed multiple Flutter apps for Android and iOS platforms, resulting in a 30% increase in user engagement and a 25% increase in app store ratings
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://boards.greenhouse.io/anthropic/jobs/4486155008")
page_data=loader.load().pop().page_content
print(page_data)
# Out:
# Job Application for Brand Designer, Events at Anthropic
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       Apply Now
#
# Brand Designer, Events
#
#     at Anthropic
#
# (View all jobs)
#
#       San Francisco, CA | New York City, NY | Seattle, WA
#
#
#
# About Anthropic
# Anthropic’s mission is to create reliable, interpretable, and steerable AI systems. We want AI to be safe and beneficial for our users and for society as a whole. Our team is a quickly growing group of committed researchers, engineers, policy experts, and business leaders working together to build beneficial AI systems.
# About the role
# Anthropic is seeking an Event Designer to lead our brand presence through physical and digital experiences. You’ll drive the creative direction for our B2B events portfolio focused on field marketing and sales.
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_exract = PromptTemplate.from_template(
    """
    ###SCRAPED TEXT FROM WEBSITE:
    {page_data}
    ###INSTRUCTION:
    The scraped text is from the career's page of a website.
    Your job is to extract the job postings and return them in JSON format containing the 
    following keys:"role","teams","positions","skills",and "description"
    """
)
chain_extract = prompt_exract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
print(res.content)
# Out:
# Here is the extracted job posting in JSON format:
#
# ```
# {
#   "role": "Brand Designer, Events",
#   "teams": "Events",
#   "positions": "San Francisco, CA | New York City, NY | Seattle, WA",
#   "skills": [
#     "Extensive experience designing end-to-end B2B event experiences",
#     "Presentation design, content marketing, physical build-outs, and digital touchpoints",
#     "Strategic planning, hands-on design execution, and partnership building",
#     "Making complex technical topics clear and engaging",
#     "Balancing high design standards with practical constraints"
#   ],
#   "description": "Anthropic is seeking an Event Designer to lead our brand presence through physical and digital experiences. You’ll drive the creative direction for our B2B events portfolio focused on field marketing and sales. You'll partner closely with the brand team and the Head of Events to transform our business and product objectives into memorable experiences."
# }
# ```
#
# ...

# %%
from langchain_core.output_parsers import JsonOutputParser
json_parser=JsonOutputParser()
json_res=json_parser.parse(res.content)
json_res
# Out:
# {'role': 'Brand Designer, Events',
#  'teams': 'Events',
#  'positions': 'San Francisco, CA | New York City, NY | Seattle, WA',
#  'skills': ['Extensive experience designing end-to-end B2B event experiences',
#   'Presentation design, content marketing, physical build-outs, and digital touchpoints',
#   'Strategic planning, hands-on design execution, and partnership building',
#   'Making complex technical topics clear and engaging',
#   'Balancing high design standards with practical constraints'],
#  'description': "Anthropic is seeking an Event Designer to lead our brand presence through physical and digital experiences. You’ll drive the creative direction for our B2B events portfolio focused on field marketing and sales. You'll partner closely with the brand team and the Head of Events to transform our business and product objectives into memorable experiences."}

# %%
import pandas as pd
df= pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# ...

# %%
import uuid
import chromadb
client=chromadb.PersistentClient('vectorstore')
collection=client.get_or_create_collection(name="portfolio")
if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                      metadatas={"links":row["Links"]},
                      ids=[str(uuid.uuid4())])

# %%
job=json_res
job['skills']
# Out:
# ['Extensive experience designing end-to-end B2B event experiences',
#  'Presentation design, content marketing, physical build-outs, and digital touchpoints',
#  'Strategic planning, hands-on design execution, and partnership building',
#  'Making complex technical topics clear and engaging',
#  'Balancing high design standards with practical constraints']

# %%
links=collection.query(query_texts=["Experience in Python","Experience in React Native"])
links
# Out:
# {'ids': [['c44936ef-67b2-40fb-a5eb-ad677c6d8c8c',
#    'a4d3fb43-595d-4939-b74b-169af7c28c53',
#    '47bb92ed-396d-45f1-a320-46ce25bd0505',
#    '43c209f3-c42f-40b0-a5ce-e78fe659c9e0',
#    '9b3826c7-fd1d-4213-a5b8-c31613c8587d',
#    'ab8295ad-3a9c-44a1-ba84-803056c645bc',
#    '00d9c80f-b9f1-4fc0-badf-e31b541d4fa8',
#    'd6f5a146-972c-4160-be80-67030b4fda40',
#    '9822216b-fee0-4d6a-9acb-a9b5a41ff430',
#    '453478fe-8c1a-465b-8bcb-e7d41fcf819d'],
#   ['cdcfce4a-7f03-4a60-97f6-0e55c4bc0fa1',
#    'd07a9ca6-2448-4c59-a26f-61a7473a8819',
#    '00d9c80f-b9f1-4fc0-badf-e31b541d4fa8',
#    '9822216b-fee0-4d6a-9acb-a9b5a41ff430',
#    '1bf3c1dd-dd46-4116-b1e0-7f529c89eddf',
#    '453478fe-8c1a-465b-8bcb-e7d41fcf819d',
#    '951ab67c-5c64-4135-9689-a868224ce9c5',
#    'ab8295ad-3a9c-44a1-ba84-803056c645bc',
#    'c1e577d8-0a94-402e-80fa-84b8732b6339',
#    '1dd45786-1205-4726-85b1-6ed884648b65']],
#  'distances': [[0.9968848007555503,
#    1.0578701721493369,
#    1.5701058255556164,
# ...

# %%
prompt_email = PromptTemplate.from_template(
    """
    ### JOB DESCRIPTION:
            {job_description}

            ### INSTRUCTION:
            You are Mohan, a business development executive at AtliQ. AtliQ is an AI & Software Consulting company dedicated to facilitating
            the seamless integration of business processes through automated tools. 
            Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
            process optimization, cost reduction, and heightened overall efficiency. 
            Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ 
            in fulfilling their needs.
            Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
            Remember you are Mohan, BDE at AtliQ. 
            Do not provide a preamble.
            ### EMAIL (NO PREAMBLE):
    """
)
chain_email = prompt_email | llm 
res = chain_email.invoke({"job_description":str(job),'link_list':links})
print(res.content)
# Out:
# Subject: Expert Brand Designer for Your B2B Event Experiences
#
# Dear Hiring Manager,
#
# I came across the Brand Designer, Events role at Anthropic and was impressed by the company's commitment to creating memorable B2B event experiences. As a business development executive at AtliQ, I believe our team can help you achieve your goals.
#
# AtliQ is an AI & Software Consulting company with a proven track record of empowering enterprises with tailored solutions, fostering scalability, process optimization, cost reduction, and heightened overall efficiency. Our expertise in designing end-to-end experiences, presentation design, content marketing, physical build-outs, and digital touchpoints aligns perfectly with your requirements.
#
# ...
